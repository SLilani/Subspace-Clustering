# %%
import bib.dataplayer as dtp
import bib.clique as clique
import matplotlib.pyplot as plt
import bib.Evaluateur_inertie as ei
import bib.outils as tools

# %%
# Fonction de teste 
# Prend en paramétre base : Dataframe, nb_intervalles : nombre d'intervalles pour la discrétisation des dimensions
# et le taux : pour la densité des cellules
def test_clique(base,nb_intervalles,taux) :
    clique_test = clique.clique(base,nb_intervalles,taux)
    clique_test.run()
    clique_test.affichage_clique()
    aff,centro = clique_test.output_for_eval_inertie()
    e = ei.Evaluateur_inertie(base,aff,centro)
    e.Evaluate(tools.euclidienne)
    e.__str__()

# %%
##########################################################################################################################
################################################### TESTS CLIQUE #########################################################
##########################################################################################################################

# %%
################################################ TEST XOR ################################################################
nb_points = 100
var = 0.005
        
data_test_one = dtp.create_xor(nb_points,var)
test_clique(data_test_one,3,0.1)
# Out:
# C:\Users\MDK\Documents\SCLUSTERING\Subspace-Clustering-master\bib\outils.py:71: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   resultat[i] = resultat[i].reshape(len(resultat[i])/2,2)
# les clusters pour la dimension  0  sont  :
# les clusters pour la dimension  1  sont  :
# les clusters pour la dimension  01  sont  :
# Résultat de l'évaluation :
#
# Inertie intra-classes : 110.04810612705195
#
# Inertie inter-classes : 1.5617245978494319
#
# Inertie totale-classes : 111.60983072490139

# %%
####################################### TEST GAUSSIENNES VERTICALES PARALLELES ###########################################
nb_points = 100       
data_test_two = dtp.create_gauss_vertical(nb_points)
test_clique(data_test_two,3,0.01)
# Out:
# les clusters pour la dimension
# C:\Users\MDK\Documents\SCLUSTERING\Subspace-Clustering-master\bib\outils.py:71: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   resultat[i] = resultat[i].reshape(len(resultat[i])/2,2)
# 0  sont  :
# les clusters pour la dimension  1  sont  :
# les clusters pour la dimension  01  sont  :
# Résultat de l'évaluation :
#
# Inertie intra-classes : 27.792095855374715
#
# Inertie inter-classes : 0.5702333919599304
#
# Inertie totale-classes : 28.362329247334646

# %%
######################################### TEST GAUSSIENNES HORIZONTALES PARALLELES #######################################
nb_points =100     
data_test_two = dtp.create_gauss_horizontal(nb_points)
test_clique(data_test_two,3,0.01)
# Out:
# les clusters pour la dimension  0  sont  :
# C:\Users\MDK\Documents\SCLUSTERING\Subspace-Clustering-master\bib\outils.py:71: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   resultat[i] = resultat[i].reshape(len(resultat[i])/2,2)
# les clusters pour la dimension  1  sont  :
# les clusters pour la dimension  01  sont  :
# Résultat de l'évaluation :
#
# Inertie intra-classes : 29.702308227782975
#
# Inertie inter-classes : 0.6222381036491089
#
# Inertie totale-classes : 30.324546331432085

# %%
################################################ TEST GAUSSIENNES HORIZONTALES centre ############################################
nb_points =100     
data_test_two = dtp.create_gauss_horizontal_cent(nb_points)
test_clique(data_test_two,3,0.05)
# Out:
# les clusters pour la dimension  0  sont  :
# C:\Users\MDK\Documents\SCLUSTERING\Subspace-Clustering-master\bib\outils.py:71: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   resultat[i] = resultat[i].reshape(len(resultat[i])/2,2)
# les clusters pour la dimension  1  sont  :
# les clusters pour la dimension  01  sont  :
# Résultat de l'évaluation :
#
# Inertie intra-classes : 19.6273035383595
#
# Inertie inter-classes : 0.5587470970663415
#
# Inertie totale-classes : 20.18605063542584

# %%
################################################ TEST GAUSSIENNES HORIZONTALES centre ############################################
nb_points =100     
data_test_two = dtp.create_gauss_vertical_cent(nb_points)
test_clique(data_test_two,3,0.01)
# Out:
# les clusters pour la dimension  0  sont  :
# C:\Users\MDK\Documents\SCLUSTERING\Subspace-Clustering-master\bib\outils.py:71: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   resultat[i] = resultat[i].reshape(len(resultat[i])/2,2)
# les clusters pour la dimension  1  sont  :
# les clusters pour la dimension  01  sont  :
# Résultat de l'évaluation :
#
# Inertie intra-classes : 21.348376045829053
#
# Inertie inter-classes : 0.528798086603895
#
# Inertie totale-classes : 21.87717413243295

# %%
################################################ TEST GAUSSIENNES HORIZONTALES centre ############################################
nb_points =100     
data_test_two = dtp.create_gauss_cross(nb_points)
test_clique(data_test_two,10,0.01)
# Out:
# C:\Users\MDK\Documents\SCLUSTERING\Subspace-Clustering-master\bib\outils.py:71: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   resultat[i] = resultat[i].reshape(len(resultat[i])/2,2)
# les clusters pour la dimension  0  sont  :
# les clusters pour la dimension  1  sont  :
# les clusters pour la dimension  01  sont  :
# Résultat de l'évaluation :
#
# Inertie intra-classes : 13.453190717937218
#
# Inertie inter-classes : 0.0515182992827155
#
# Inertie totale-classes : 13.504709017219934
